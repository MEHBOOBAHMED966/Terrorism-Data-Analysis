# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df=pd.read_csv('C:\\Users\\This\\OneDrive\\Desktop\\SQL\\global.csv')
# Out:
# C:\Users\This\anaconda3\New folder\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
pd. set_option("display.max_columns", None) 
df.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region                   region_txt provstate  \
# 0  Dominican Republic       2  Central America & Caribbean       NaN
# 1              Mexico       1                North America   Federal
# 2         Philippines       5               Southeast Asia    Tarlac
# 3              Greece       8               Western Europe    Attica
# 4               Japan       4                    East Asia   Fukouka
#
#             city   latitude   longitude  specificity  vicinity location  \
# ...

# %%
df.tail(3)
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
#         country  country_txt  region      region_txt    provstate  \
# 181688      160  Philippines       5  Southeast Asia  Maguindanao
# 181689       92        India       6      South Asia      Manipur
# 181690      160  Philippines       5  Southeast Asia  Maguindanao
#
#                  city   latitude   longitude  specificity  vicinity  \
# 181688       Kubentog   6.900742  124.437908          2.0         0
# 181689         Imphal  24.798346   93.940430          1.0         0
# 181690  Cotabato City   7.209594  124.241966          1.0         0
#
#                                                  location  \
# 181688  The incident occurred in the Datu Hoffer distr...
# ...

# %%
df.shape
# Out:
# (181691, 135)

# %%
df.isnull().sum()
# Out:
# eventid            0
# iyear              0
# imonth             0
# iday               0
# approxdate    172452
#                ...
# INT_LOG            0
# INT_IDEO           0
# INT_MISC           0
# INT_ANY            0
# related       156653
# Length: 135, dtype: int64

# %%
df.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
df.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002705e+11    2002.638997       6.467277      15.505644
# std    1.325957e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991021e+11    1991.000000       4.000000       8.000000
# 50%    2.009022e+11    2009.000000       6.000000      15.000000
# 75%    2.014081e+11    2014.000000       9.000000      23.000000
# max    2.017123e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# ...

# %%
countries=df.country_txt.value_counts().head(10)

# %%
countries
# Out:
# Iraq              24636
# Pakistan          14368
# Afghanistan       12731
# India             11960
# Colombia           8306
# Philippines        6908
# Peru               6096
# El Salvador        5320
# United Kingdom     5235
# Turkey             4292
# Name: country_txt, dtype: int64

# %%
plt.figure(figsize=(17,5))
plt.bar(countries.index,countries.values, color='b')
plt.title('Top 10 countries with most terrorism')
plt.xlabel('countries')
plt.ylabel('count')
plt.style.use('seaborn')
plt.show()

# %%
countries=df.country_txt.value_counts().tail(10)
plt.figure(figsize=(17,5))
plt.bar(countries.index,countries.values, color='pink')
plt.title('Top 10 countries with least terrorism')
plt.xlabel('countries')
plt.ylabel('count')
plt.style.use('seaborn')
plt.show()

# %% [markdown]
# # Top 10 Countries Terrorism Occur Ratio Wise

# %%
country=df.country_txt.value_counts().head(10)
plt.figure(figsize=(13,5))
plt.pie(country.values, labels=country.index, radius=2, autopct='%0.1f%%')
plt.style.use('seaborn')
plt.show()

# %%
toyear=df.groupby(['iyear','country_txt'])['eventid'].agg(['count']).reset_index().sort_values(by='count',ascending=False).head(10)

# %%
toyear.head(20)
# Out:
#       iyear  country_txt  count
# 3392   2014         Iraq   3933
# 3596   2016         Iraq   3360
# 3299   2013         Iraq   2852
# 3492   2015         Iraq   2751
# 3698   2017         Iraq   2466
# 3322   2013     Pakistan   2215
# 3421   2014     Pakistan   2151
# 3453   2015  Afghanistan   1928
# 3353   2014  Afghanistan   1824
# 3230   2012     Pakistan   1654

# %%
plt.figure(figsize=(15,5))
sns.countplot(df["iyear"],order=df['iyear'].value_counts(ascending=False).head(10).index,palette="dark")
plt.xlabel("Year",fontsize=15)
plt.ylabel("Count",fontsize=15)
plt.title("Top Most Terrorism Attack Years",fontsize=20)
plt.show()
# Out:
# C:\Users\This\anaconda3\New folder\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
lessyear=df.groupby('iyear')['eventid'].agg(['count']).reset_index().sort_values(by='count',ascending=True).head(10)
lessyear
# Out:
#     iyear  count
# 1    1971    471
# 3    1973    473
# 2    1972    568
# 4    1974    581
# 0    1970    651
# 5    1975    740
# 6    1976    923
# 27   1998    934
# 33   2004   1166
# 32   2003   1278

# %%
plt.figure(figsize=(15,5))
sns.countplot(df['iyear'], order=df['iyear'].value_counts(ascending=False).tail(10).index,palette='bright')
plt.xlabel("Year",fontsize=15)
plt.ylabel("Count",fontsize=15)
plt.title("Top Less Terrorism Attack Years",fontsize=20)
plt.show()
# Out:
# C:\Users\This\anaconda3\New folder\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Top 10 Most Terrorism Attack Years Ratio Wise

# %%
year=df.iyear.value_counts().head(10)
plt.figure(figsize=(16,5))
plt.pie(year.values,labels=year.index,radius=2,autopct='%0.1f%%')
plt.show()
plt.style.use("seaborn")

# %% [markdown]
# # Top 10 Terror Attacks Type By Terrorist

# %%
attack=df.attacktype1_txt.value_counts().head(10)
plt.figure(figsize=(18,8))
plt.bar(attack.index,attack.values,color='b')
plt.xlabel("Attacks")
plt.ylabel("Values")

# %%
attack=df.attacktype2_txt.value_counts().head(10)
plt.figure(figsize=(18,8))
plt.bar(attack.index,attack.values,color='b')
plt.xlabel("Attacks")
plt.ylabel("Values")
# Out:
# Text(0, 0.5, 'Values')

# %%
attack=df.attacktype3_txt.value_counts().head(10)
plt.figure(figsize=(18,8))
plt.bar(attack.index,attack.values,color='b')
plt.xlabel("Attacks")
plt.ylabel("Values")
# Out:
# Text(0, 0.5, 'Values')

# %% [markdown]
# # Top 10 Most Target Places

# %%
target=df['targsubtype1_txt'].value_counts().head(5)
plt.figure(figsize=(16,6))
plt.bar(target.index,target.values,color='r')
plt.xlabel('Targets')
plt.ylabel('Values')
plt.show()

# %%
target=df['targsubtype2_txt'].value_counts().head(5)
plt.figure(figsize=(16,6))
plt.bar(target.index,target.values,color='r')
plt.xlabel('Targets')
plt.ylabel('Values')
plt.show()

# %%
target=df['targsubtype3_txt'].value_counts().head(5)
plt.figure(figsize=(18,6))
plt.bar(target.index,target.values,color='r')
plt.xlabel('Targets')
plt.ylabel('Values')
plt.show()

# %% [markdown]
# # Top 10 Cities In Which Terrorism Occur

# %%
topcity=df.city.value_counts().head(10)
plt.figure(figsize=(14,6))
plt.title('Top 10 Cities in Which Terrorism Occur')
plt.bar(topcity.index,topcity.values,color='y')
plt.show()

# %% [markdown]
# # Terrorism By Years

# %%
plt.figure(figsize=(16,8))
sns.countplot(df["iyear"],order=df['iyear'].value_counts().index,palette="bright")
plt.xticks(rotation=90)
plt.xlabel("Year",fontsize=15)
plt.ylabel("Count",fontsize=15)
plt.title("Attack per year",fontsize=20)
plt.show()
# Out:
# C:\Users\This\anaconda3\New folder\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Report
# Iraq has the most effective country With Terrorism
# Vatican City, North Korea less effective contry with Terrorism
# In 2014 Most Terrorist Attack Occur
# In 2017 Least Terrorist Attack Occur
# Terrorism Ratio in 2014 more than rest of the years
# Most Terrorist Attacks On Civilians
# Most Of the Terrorist Attack Through Bombing,Armed Assault and Facility Attacks¶
